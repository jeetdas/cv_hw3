# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/jeetdas/miniconda3/envs/cv_hw5_1/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

def generate_laplacian_pyramid(input_image, sigma_values):
    laplacian_pyramid = []

    for sigma in sigma_values:
        smoothed_image = cv2.GaussianBlur(input_image, ksize=(0, 0), sigmaX=sigma, sigmaY=sigma)
        laplacian_image = cv2.Laplacian(smoothed_image, ddepth=cv2.CV_64F)
        laplacian_pyramid.append(laplacian_image)

    return laplacian_pyramid

# %%
t = generate_laplacian_pyramid(loaded_img, [2])
t
# Out:
# [array([[  0.,   0.,   0., ..., -10., -17., -22.],
#         [ -1.,  -1.,   0., ...,  -8., -15., -15.],
#         [  1.,   2.,  -2., ...,  -2.,  -5., -11.],
#         ...,
#         [ -1.,  -2.,  -2., ...,  -1.,   0.,  -2.],
#         [ -1.,  -4.,   0., ...,  -1.,   0.,  -2.],
#         [ -4.,   0.,  -5., ...,  -1.,   0.,  -2.]])]

# %%
path_of_img = "../flarsheim-1.jpg"
loaded_img = cv2.imread(path_of_img, cv2.IMREAD_GRAYSCALE)

scale_values = [1, 2, 4, 8]

log_stack_images = generate_laplacian_pyramid(loaded_img, scale_values)

plt.figure(figsize=(10, 10))
for index, img in enumerate(log_stack_images):
    plt.subplot(1, len(scale_values), index + 1)
    plt.imshow(img)
plt.show()

# %%
# trying with even higher scales for samples
path_of_img = "../flarsheim-1.jpg"
loaded_img = cv2.imread(path_of_img, cv2.IMREAD_GRAYSCALE)

scale_values = [2, 8, 9, 10.5]
log_stack_images = generate_laplacian_pyramid(loaded_img, scale_values)

plt.figure(figsize=(10, 10))
for index, img in enumerate(log_stack_images):
    plt.subplot(1, len(scale_values), index + 1)
    plt.imshow(img)
plt.show()
