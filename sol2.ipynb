# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

path_of_img = "../flarsheim-1.jpg"
loaded_img = cv2.imread(path_of_img, cv2.IMREAD_GRAYSCALE)

scale_values = [1, 2, 4, 8]

log_stack_images = generate_laplacian_pyramid(loaded_img, scale_values)

# Choose the first scale's Laplacian of Gaussian (LoG) image for demonstration
selected_log_image = log_stack_images[0]

# Pick a specific row from the selected LoG image for plotting
chosen_row_index = 100  # This index can be any valid row number
selected_row_data = selected_log_image[chosen_row_index, :]

# Create x-axis coordinates for the row data to be plotted
x_axis_coordinates = np.arange(selected_row_data.size)

# Detect extrema in the LoG image using the previously defined function
extrema_x, extrema_y, extrema_scale = extract_scale_space_extrema(loaded_img, log_stack_images, 0.1, scale_values)

# Set up the plot for the selected LoG image
plt.figure(figsize=(25, 5))
plt.imshow(selected_log_image, cmap='gray')
plt.title('Laplacian of Gaussian (LoG) Image at First Scale')
plt.axis('off')  # Hide the axis for a cleaner look

# Display the plot
plt.show()
